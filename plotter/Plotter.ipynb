# %%
import matplotlib.pyplot as plt
import numpy as np

from importlib import reload

import DataReader as DataReader
import Plotter as Plotter

# %%
reload(DataReader)
reload(Plotter)
# Out:
# <module 'Plotter' from '/home/caioc/facul/IC/CBOpticalNet/plotter/Plotter.py'>

# %%
num_nodes = [ 128 ] # Fixed number of nodes
datasets = [
    "tor"
]
switch_sizes = [ 64 ]
num_sims = 30

# %%
tor_data = []

# %%
for dataset in datasets:
    for num_node in num_nodes:
        for switch_size in switch_sizes:
            if switch_size == -1:
                switch_size = 2 * num_node

            elif switch_size <= 16 and num_node >= 256:
                continue

            elif switch_size <= 64 and num_node >= 512:
                continue
            
            elif switch_size == 256 and num_node == 128:
                continue

            tor_data.append(DataReader.DataReader(dataset, "cbOptNet", num_node, switch_size, num_sims))
            
tor_data = np.array(tor_data)

# %%
print(tor_data)
# Out:
# [DataReader(dataset='tor', project='cbOptNet', num_nodes=128, switch_size=64, num_sims=30, switch_ports=32, num_switches_1=16, num_switches_2=24, max_rounds=52646)]

# %%
slc = [ 0 ]

# %%
print(tor_data[slc])
# Out:
# [DataReader(dataset='tor', project='cbOptNet', num_nodes=128, switch_size=64, num_sims=30, switch_ports=32, num_switches_1=16, num_switches_2=24, max_rounds=52646)]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF Switches ativos por rounds")
ax.set_xlabel("Rounds x 10^3")
ax.set_ylabel("Porcentagem dos switches ativos")

for data in tor_data[slc]:
    Plotter.Plotter.cdf_active_switches(data.cdf_active_switches(), ax)

ax.legend([ f"{data.num_nodes}|{data.num_switches} nodes|switches" for data in tor_data[slc] ], loc="best")

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF % portas ativas por Switch")
ax.set_xlabel("Porcentagem de portas ativas")
ax.set_ylabel("Porcentagem dos switches")

for data in tor_data[slc]:
    Plotter.Plotter.cdf_active_switches(data.cdf_switch_active_ports(), ax)
    
ax.legend([ f"{data.num_nodes}|{data.num_switches} nodes|switches" for data in tor_data[slc] ], loc="best")

# %%
reload(DataReader)
reload(Plotter)
# Out:
# <module 'Plotter' from '/home/caioc/facul/IC/CBOpticalNet/plotter/Plotter.py'>

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF Portas ativas por rounds")
ax.set_xlabel("Número de rounds")
ax.set_ylabel("Porcentagem das portas ativas")

for data in tor_data[slc]:
    Plotter.Plotter.cdf_active_ports(data.cdf_active_ports(), ax)

ax.legend([ f"{data.num_nodes}|{data.num_switches} nodes|switches" for data in tor_data[slc] ], loc="best")
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_349876/4268225318.py", line 7, in <cell line: 6>
#     Plotter.Plotter.cdf_active_ports(data.cdf_active_ports(), ax)
#   File "/home/caioc/facul/IC/CBOpticalNet/plotter/Plotter.py", line 184, in cdf_active_ports
#     ax.set_xscale("probability", points=x, vmin=0.01)
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/matplotlib/axes/_base.py", line 3777, in set_xscale
#     ax.xaxis._set_scale(value, **kwargs)
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/matplotlib/axis.py", line 761, in _set_scale
#     self._scale = mscale.scale_factory(value, self, **kwargs)
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/matplotlib/scale.py", line 597, in scale_factory
#     return scale_cls(axis, **kwargs)
#   File "/home/caioc/facul/IC/CBOpticalNet/plotter/Plotter.py", line 41, in __init__
#     mscale.ScaleBase.__init__(self)
# TypeError: ScaleBase.__init__() missing 1 required positional argument: 'axis'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 1982, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/home/caioc/.pyenv/versions/3.10.0/lib/python3.10/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF roteamentos por nó")
ax.set_xlabel("Roteamentos x 10^3")
ax.set_ylabel("Porcentagem dos nós")

for data in tor_data[slc]:
    Plotter.Plotter.cdf_routings(data.cdf_node_routings(), ax)

ax.legend([ f"{data.num_nodes}|{data.num_switches} nodes|switches" for data in tor_data[slc] ], loc="best")

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF alterações por nó")
ax.set_xlabel("Alterações")
ax.set_ylabel("Porcentagem dos nós")

for data in tor_data[slc]:
    Plotter.Plotter.cdf_alterations(data.cdf_node_alterations(), ax)

ax.legend([ f"{data.num_nodes}|{data.num_switches} nodes|switches" for data in tor_data[slc] ], loc="best")

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF roteamentos por switch")
ax.set_xlabel("Roteamentos x 10^3")
ax.set_ylabel("Porcentagem dos switches")

for data in tor_data[slc]:
    Plotter.Plotter.cdf_routings(data.cdf_switch_routings(), ax)

ax.legend([ f"{data.num_nodes}|{data.num_switches} nodes|switches" for data in tor_data[slc] ], loc="best")

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF alterações por switch")
ax.set_xlabel("Alterações")
ax.set_ylabel("Porcentagem dos switches")

for data in tor_data[slc]:
    Plotter.Plotter.cdf_alterations(data.cdf_switch_alterations(), ax)

ax.legend([ f"{data.num_nodes}|{data.num_switches} nodes|switches" for data in tor_data[slc] ], loc="best")

# %%
import matplotlib.pyplot as plt
import numpy as np

from importlib import reload

import DataReader as DataReader
import Plotter as Plotter

# %%
reload(DataReader)
reload(Plotter)
# Out:
# <module 'Plotter' from '/home/caioc/facul/IC/CBOpticalNet/plotter/Plotter.py'>

# %%
data = [ DataReader.DataReader("tor", "cbOptNet", 128, n_switches, 30) for n_switches in (128, 256) ]

# %%
alterations = [ swt_data.read_alterations(switch_alterations=True)[0] for swt_data in data ]
routings = [ swt_data.read_routings(switch_routings=True)[0] for swt_data in data ]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF Switches ativos por rounds")
ax.set_xlabel("Rounds x 10^4")
ax.set_ylabel("Porcentagem dos switches ativos")

for alt, rout in zip(alterations, routings):
    Plotter.Plotter.cdf_active_switches(alt, rout, ax)

ax.legend([ f"{swt_data.num_switches} switches" for swt_data in data ], loc="best")

# %%
total_alt_ports = [ swt_data.read_total_alterations(altered_ports=True, sims=1)[0] for swt_data in data ]
total_rout_ports = [ swt_data.read_total_routings(routing_ports=True, sims=1)[0] for swt_data in data ]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF Portas ativas por rounds")
ax.set_xlabel("Porcentagem dos rounds")
ax.set_ylabel("Porcentagem das portas ativas")

for alt, rout in zip(total_alt_ports, total_rout_ports):
    Plotter.Plotter.cdf_active_ports(alt, rout, ax)

ax.legend([ f"{swt_data.num_switches} switches" for swt_data in data ], loc="best")

# %%
alt_swt_ports = [ swt_data.read_altered_ports(per_switch=True, sims=1)[0] for swt_data in data ]
rout_swt_ports = [ swt_data.read_routing_ports(per_switch=True, sims=1)[0] for swt_data in data ]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF % portas ativas por Switch")
ax.set_xlabel("Porcentagem de portas ativas")
ax.set_ylabel("Porcentagem dos switches")

for alt, rout in zip(alt_swt_ports, rout_swt_ports):
    Plotter.Plotter.cdf_switches_active_ports(alt, rout, ax)

ax.legend([ f"{swt_data.num_switches} switches" for swt_data in data ], loc="best")

# %%
node_routs = [ swt_data.read_total_routings(nodes_routings=True)[0] for swt_data in data ]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF roteamentos por nó")
ax.set_xlabel("Roteamentos x 10^4")
ax.set_ylabel("Porcentagem dos nós")

for rout in node_routs:
    Plotter.Plotter.cdf_routings(rout, ax)

ax.legend([ f"{swt_data.num_switches} switches" for swt_data in data ], loc="best")

# %%
node_alts = [ swt_data.read_total_alterations(nodes_alterations=True)[0] for swt_data in data ]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF alterações por nó")
ax.set_xlabel("Alterações")
ax.set_ylabel("Porcentagem dos nós")

for alt in node_alts:
    Plotter.Plotter.cdf_alterations(alt, ax)

ax.legend([ f"{swt_data.num_switches} switches" for swt_data in data ], loc="best")

# %%
switch_routs = [ swt_data.read_total_routings(switch_routings=True)[0] for swt_data in data ]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF roteamentos por switch")
ax.set_xlabel("Roteamentos x 10^4")
ax.set_ylabel("Porcentagem dos switches")

for rout in switch_routs:
    Plotter.Plotter.cdf_routings(rout, ax)

ax.legend([ f"{swt_data.num_switches} switches" for swt_data in data ], loc="best")

# %%
switch_alts = [ swt_data.read_total_alterations(switch_alterations=True)[0] for swt_data in data ]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title("CDF alterações por switch")
ax.set_xlabel("Alterações")
ax.set_ylabel("Porcentagem dos switches")

for alt in switch_alts:
    Plotter.Plotter.cdf_alterations(alt, ax)

ax.legend([ f"{swt_data.num_switches} switches" for swt_data in data ], loc="best")
